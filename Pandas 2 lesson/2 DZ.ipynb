# %%
import pandas as pd

# %%
taxi = pd.read_csv("2_taxi_nyc.csv")

# %%
taxi.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
taxi.shape
# Out:
# (29101, 14)

# %%
taxi.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
taxi.dtypes.value_counts()
# Out:
# float64    9
# object     4
# int64      1
# Name: count, dtype: int64

# %%
taxi.rename(columns= {'pcp 01': 'pcp_o1','pcp 06': 'pcp_o6', 'pcp 24': 'pcp_24'} ).head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_o1  pcp_o6  pcp_24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
#Сколько заказов в Бруклине
taxi.query("borough == 'Brooklyn'").shape[0]
# Out:
# 4343

# %%
taxi.groupby("borough").agg({'hday' : 'count'})
# Out:
#                hday
# borough
# Bronx          4343
# Brooklyn       4343
# EWR            4343
# Manhattan      4343
# Queens         4343
# Staten Island  4343

# %%
taxi.borough.value_counts()
# Out:
# borough
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: count, dtype: int64

# %%
all_pickups = taxi.pickups.sum()

# %%
taxi.groupby('borough').agg({'pickups': 'sum'}).idxmax()['pickups']
# Out:
# 'Manhattan'

# %%
taxi.groupby(['borough', 'hday'], as_index=False).agg({'pickups' : 'mean'})
# Out:
#           borough hday      pickups
# 0           Bronx    N    50.771073
# 1           Bronx    Y    48.065868
# 2        Brooklyn    N   534.727969
# 3        Brooklyn    Y   527.011976
# 4             EWR    N     0.023467
# 5             EWR    Y     0.041916
# 6       Manhattan    N  2401.302921
# 7       Manhattan    Y  2035.928144
# 8          Queens    N   308.899904
# 9          Queens    Y   320.730539
# 10  Staten Island    N     1.606082
# 11  Staten Island    Y     1.497006

# %%
taxi.groupby(['borough','pickup_month'], as_index=False).aggregate({'pickups': 'sum'}).sort_values('pickups', ascending=False)
# Out:
#           borough pickup_month  pickups
# 21      Manhattan          Jun  1995388
# 23      Manhattan          May  1888800
# 19      Manhattan          Feb  1718571
# 22      Manhattan          Mar  1661261
# 18      Manhattan          Apr  1648278
# 20      Manhattan          Jan  1455543
# 9        Brooklyn          Jun   482466
# 11       Brooklyn          May   476087
# 6        Brooklyn          Apr   378095
# 10       Brooklyn          Mar   346726
# 7        Brooklyn          Feb   328650
# 8        Brooklyn          Jan   309011
# 27         Queens          Jun   286311
# 29         Queens          May   275893
# 28         Queens          Mar   219561
# 24         Queens          Apr   216857
# 25         Queens          Feb   185695
# 26         Queens          Jan   159211
# 5           Bronx          May    53037
# 3           Bronx          Jun    49006
# 0           Bronx          Apr    34617
# 4           Bronx          Mar    32232
# ...

# %%
def temp_to_celcius(Fahrenheit):
    Celsius = ((Fahrenheit-32) *5.0)/(9.0)
    return Celsius

# %%
temp_to_celcius(taxi.temp).head()
# Out:
# 0   -1.111111
# 1   -1.111111
# 2   -1.111111
# 3   -1.111111
# 4   -1.111111
# Name: temp, dtype: float64
